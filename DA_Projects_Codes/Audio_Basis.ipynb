# %% [markdown]
# <a href="https://colab.research.google.com/github/Dharma-Ranganathan/AllAboutPython/blob/main/DA_Projects_Codes/Audio_Basis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import librosa as la

# %%
audio_path = '/content/drive/MyDrive/Audio /marco_song.mp3'

# %%
audio_np,sr = la.load(audio_path,sr=None)

# %%
audio_np
# Out:
# array([ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#        -2.1989641e-07,  2.5472487e-05, -2.3526923e-06], dtype=float32)

# %%
sr
# Out:
# 44100

# %%
audio_np.shape
# Out:
# (1186816,)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(audio_np,color='g')
plt.show()
