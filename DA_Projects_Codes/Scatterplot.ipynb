# %% [markdown]
# <a href="https://colab.research.google.com/github/Dharma-Ranganathan/AllAboutPython/blob/main/Scatterplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Custom scatter plot

# %% [markdown]
# Importing required libraries

# %%
# numpy
import numpy as np

# %%
# matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# Creating custom datasets using numpy

# %%
# using linspace for evenly spaced values
x = np.linspace(1,10,100)

# %% [markdown]
# Creating sine and cosine values of x

# %%
# sine values
y = np.sin(x)

# cosine values
z = np.cos(x)

# %% [markdown]
# Creating scatter plot

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.scatter(x,y,c='r',marker='o')
ax.scatter(x,z,c='g',marker='x')
plt.xlabel('angles(theta)')
plt.ylabel('sine and cosine')
plt.title('sine vs cosine')
plt.show()

# %%
plt.plot(x,y,'r--')
plt.plot(x,z,'g:')
plt.show()
